# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import json

# %%
# load test data
dir = "C:\\Users\\E123108\\Dropbox\\Programming\\Python\\Qscope\\mock_output\\2025\\2025-04\\2025-04-15_data\\"

esr_data = np.load(dir + '0000_ESR_sweep.npy')
data_dict = json.load(open(dir + '0000_ESR_sweep_w_fit.json', 'r'))
f_list = data_dict['x']

meta_dict = json.load(open(dir + '0000_ESR_metadata.json', 'r'))

# %%
# plot the data
plt.figure(figsize=(10, 6))
plt.plot(esr_data[0,:], esr_data[1,:], 'o-')
plt.plot(esr_data[0,:], esr_data[2,:], 'o-')
plt.xlabel('Frequency (GHz)')
plt.ylabel('Signal (a.u.)')
# Out:
# Text(0, 0.5, 'Signal (a.u.)')
